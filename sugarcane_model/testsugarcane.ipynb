# %%
# !pip install tensorflow numpy matplotlib

# %%
import numpy
import matplotlib
import tensorflow
print("NumPy version:", numpy.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("TensorFlow version:", tensorflow.__version__)
# Out:
# NumPy version: 1.26.4
# Matplotlib version: 3.9.2
# TensorFlow version: 2.18.0

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
     r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\valid",
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
class_name = validation_set.class_names
print(class_name)
# Out:
# Found 2719 files belonging to 6 classes.
# ['Healthy', 'Leaf Scald', 'Mosaic', 'Red Rot', 'Rust', 'Yellow Disease']

# %%
cnn = tf.keras.models.load_model('trained_plant_disease_model.keras')

# %%
#Test Image Visualization
import cv2
image_path = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Rust\rust (2).jpeg"
# image_path= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Healthy\healthy (8).jpeg'
# image_path =r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Red Rot\redrot (38).jpeg"
# image_path=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step

# %%
print(predictions)
# Out:
# [[8.38708660e-13 1.02779386e-23 1.16467731e-06 4.00008247e-07
#   9.99998450e-01 1.90936755e-09]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 4

# %%
# Displaying the disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Test Image Visualization
import cv2
# image_path2=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\valid\Leaf Scald\leaf_scald (2).jpg"
# image_path2 = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Rust\rust (2).jpeg"
# image_path3= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Healthy\healthy (8).jpeg'
image_path2 =r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Red Rot\redrot (38).jpeg"
# image_path2=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img2= cv2.imread(image_path2)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img2)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()



image2 = tf.keras.preprocessing.image.load_img(image_path2,target_size=(128,128))
input_arr2 = tf.keras.preprocessing.image.img_to_array(image2)
input_arr2 = np.array([input_arr2])  # Convert single image to a batch.
predictions2= cnn.predict(input_arr2)
print(predictions2)

result_index2 = np.argmax(predictions2) #Return index of max element
print(result_index2)

# Displaying the disease prediction
model_prediction2 = class_name[result_index2]
plt.imshow(img2)
plt.title(f"Disease Name: {model_prediction2}")
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# [[5.8757418e-08 4.7458651e-20 1.9669901e-08 9.9993372e-01 6.4603242e-05
#   1.5760173e-06]]
# 3

# %%
#Test Image Visualization
import cv2
image_path3=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\valid\Leaf Scald\leaf_scald (2).jpg"
# image_path3 = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Rust\rust (2).jpeg"
# image_path3= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Healthy\healthy (8).jpeg'
# image_path =r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Red Rot\redrot (38).jpeg"
# image_path=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img3= cv2.imread(image_path3)
img3 = cv2.cvtColor(img3,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img3)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()



image3 = tf.keras.preprocessing.image.load_img(image_path3,target_size=(128,128))
input_arr3 = tf.keras.preprocessing.image.img_to_array(image3)
input_arr3 = np.array([input_arr3])  # Convert single image to a batch.
predictions3 = cnn.predict(input_arr3)
print(predictions3)

result_index3 = np.argmax(predictions3) #Return index of max element
print(result_index3)

# Displaying the disease prediction
model_prediction3 = class_name[result_index3]
plt.imshow(img3)
plt.title(f"Disease Name: {model_prediction3}")
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# [[4.3158111e-06 9.9999571e-01 1.0651415e-12 1.9021142e-09 4.3364767e-10
#   7.2172838e-14]]
# 1

# %%
#Test Image Visualization
import cv2
image_path4=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\valid\Mosaic\mosaic (7).jpeg"
# image_path = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Rust\rust (2).jpeg"
# image_path= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Healthy\healthy (8).jpeg'
# image_path =r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\sugarcanedata\test\Red Rot\redrot (38).jpeg"
# image_path=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img4= cv2.imread(image_path4)
img4 = cv2.cvtColor(img4,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img4)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()



image4 = tf.keras.preprocessing.image.load_img(image_path4,target_size=(128,128))
input_arr4 = tf.keras.preprocessing.image.img_to_array(image4)
input_arr4 = np.array([input_arr4])  # Convert single image to a batch.
predictions4 = cnn.predict(input_arr4)
print(predictions4)

result_index4 = np.argmax(predictions4) #Return index of max element
print(result_index4)

# Displaying the disease prediction
model_prediction4 = class_name[result_index4]
plt.imshow(img4)
plt.title(f"Disease Name: {model_prediction4}")
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# [[1.2141543e-05 4.5203346e-14 9.9993563e-01 4.1059329e-06 4.7609519e-05
#   5.4021854e-07]]
# 2
