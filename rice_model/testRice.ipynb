# %%
# !pip install tensorflow numpy matplotlib

# %%
# !pip install numpy==1.26.4

# %%
pip install --upgrade opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
import matplotlib
import tensorflow
print("NumPy version:", numpy.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("TensorFlow version:", tensorflow.__version__)
# Out:
# NumPy version: 1.26.4
# Matplotlib version: 3.9.2
# TensorFlow version: 2.18.0

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
     r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\valid",
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
class_name = validation_set.class_names
print(class_name)
# Out:
# Found 2256 files belonging to 5 classes.
# ['Bacterial Leaf Blight', 'Brown Spot', 'Healthy', 'Leaf Blast', 'Narrow Brown Spot']

# %%
cnn = tf.keras.models.load_model('trained_plant_disease_model.keras')

# %%
#Test Image Visualization
import cv2
image_path = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Narrow Brown Spot\narrow_brown (5).jpg"
# image_path= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Bacterial Leaf Blight\bacterial_leaf_blight (1).JPG'
# image_path=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step

# %%
print(predictions)
# Out:
# [[1.8702760e-05 3.4432788e-09 6.0503312e-06 4.8518854e-07 9.9997473e-01]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 4

# %%
# Displaying the disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Test Image Visualization
import cv2
image_path1 = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Leaf Blast\leaf_blast (3).jpg"
# image_path= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Bacterial Leaf Blight\bacterial_leaf_blight (1).JPG'
# image_path=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img1 = cv2.imread(image_path1)
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img1)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image1 = tf.keras.preprocessing.image.load_img(image_path1,target_size=(128,128))
input_arr1 = tf.keras.preprocessing.image.img_to_array(image1)
input_arr1 = np.array([input_arr1])  # Convert single image to a batch.
predictions1 = cnn.predict(input_arr1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step

# %%
print(predictions1)
result_index1 = np.argmax(predictions1) #Return index of max element
print(result_index1)
# Displaying the disease prediction
model_prediction1 = class_name[result_index1]
plt.imshow(img1)
plt.title(f"Disease Name: {model_prediction1}")
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# [[3.2984905e-04 4.0499248e-02 2.4425029e-04 9.5892656e-01 4.0558465e-08]]
# 3

# %%
#Test Image Visualization
import cv2
# "C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\valid\Brown Spot\brown_spot (3).jpg"
# image_path1 = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Leaf Blast\leaf_blast (3).jpg"
image_path2= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Bacterial Leaf Blight\bacterial_leaf_blight (1).JPG'
# image_path=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img2 = cv2.imread(image_path2)
img2= cv2.cvtColor(img2,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img2)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()
image2 = tf.keras.preprocessing.image.load_img(image_path2,target_size=(128,128))
input_arr2 = tf.keras.preprocessing.image.img_to_array(image2)
input_arr2 = np.array([input_arr2])  # Convert single image to a batch.
predictions2 = cnn.predict(input_arr2)

print(predictions2)
result_index2 = np.argmax(predictions2) #Return index of max element
print(result_index2)
# Displaying the disease prediction
model_prediction2 = class_name[result_index2]
plt.imshow(img2)
plt.title(f"Disease Name: {model_prediction2}")
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# [[9.9975413e-01 7.5698139e-05 4.9931361e-09 1.6947133e-04 6.5838350e-07]]
# 0

# %%
#Test Image Visualization
import cv2
image_path3=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\valid\Brown Spot\brown_spot (3).jpg"
# image_path1 = r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Leaf Blast\leaf_blast (3).jpg"
# image_path2= r'C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\ricedata\test\Bacterial Leaf Blight\bacterial_leaf_blight (1).JPG'
# image_path=r"C:\Users\abc\Desktop\Final Project\Plant_Disease_Prediction\RiceLeafsDisease(Augmented)\test\bacterial_leaf_blight\bacterial_leaf_blight (1).JPG"
# Reading an image in default mode
img3 = cv2.imread(image_path3)
img3= cv2.cvtColor(img3,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img3)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()
image3 = tf.keras.preprocessing.image.load_img(image_path3,target_size=(128,128))
input_arr3= tf.keras.preprocessing.image.img_to_array(image3)
input_arr3= np.array([input_arr3])  # Convert single image to a batch.
predictions3 = cnn.predict(input_arr3)

print(predictions3)
result_index3 = np.argmax(predictions3) #Return index of max element
print(result_index3)
# Displaying the disease prediction
model_prediction3 = class_name[result_index3]
plt.imshow(img3)
plt.title(f"Disease Name: {model_prediction3}")
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# [[3.9230557e-03 9.5241076e-01 2.9931455e-03 4.0672384e-02 6.1255503e-07]]
# 1
